# %%
task_num = 155  # Task 0 is just an illustrative example (and not eligible for points)
import sys
sys.path.append("/kaggle/input/google-code-golf-2025/code_golf_utils")
from code_golf_utils import *
show_legend()
import sys
examples = load_examples(task_num)
show_examples(examples['train'])
show_examples(examples['test'])
for ii in range(min(10,len(examples['arc-gen'])//5)):
    show_examples(examples['arc-gen'][ii:ii+5])

# %%
# %%writefile task.py
def p(g):
    g_new = []
    for i in range(len(g)):
        g_new.append(g[len(g)-i-1])
    return g_new

# %%
verify_program(task_num, examples)
