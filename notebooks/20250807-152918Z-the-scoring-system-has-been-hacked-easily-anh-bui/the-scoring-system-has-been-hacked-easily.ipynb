# %% [markdown]
# # ⚠️ Security Warning to the Organizers
#
# ---
#
# ## 📝 Purpose
#
# Dear organizers,
# I am writing this notebook **not to exploit or hack your scoring system**, but rather to **demonstrate a critical vulnerability** and **encourage improvements** in the competition infrastructure.
#
# ---
#
# ## 🔍 Vulnerability Overview
#
# In your public file `code_golf_utils.py`, specifically inside the function `verify_program`, the following line is used to measure code size in bytes:
#
# ```python
# os.path.getsize(task_path)
# ```
#
# However, because this line is executed **after importing the solution file (`task.py`)**, it opens the door for an unintended exploit.
# A participant can **override the behavior of `os.path.getsize` inside their solution**, which allows the code to **falsely report a much smaller file size**, or even a fabricated score.
#
# ---
#
# ## 💣 Example Exploit
#
# The following is a **one-liner** that can be added to any correct solution to manipulate the scoring:
#
# ```python
# import os, sys
# os.path.getsize = lambda _: -sys.float_info.max + 2500 + 0.001 * 400
# ```
#
# This expression will fool the scoring logic into thinking that the submission is as small as possible — effectively **maximizing the score** for all 400 tasks:
#
# - `2500` is the maximum score per task.
# - `0.001 * 400` is the total penalty for incorrect tasks (zero in this case).
# - `-sys.float_info.max` is used to cancel out any actual size and force the score computation logic to return `sys.float_info.max`.
#
# This kind of override is **fully legal in Python**, and unless the scoring is done in a secure sandbox or separate process, it will execute without error.
#
# ---
#
# ## 🔐 Why This Matters
#
# This vulnerability makes it possible for:
#
# - Submissions to **pass all tests legitimately**, but still **gain unfair advantage** in scoring.
# - **Malicious code to interfere** with the evaluation process, potentially affecting leaderboard integrity.
# - Participants to **automatically get top scores** using trivial workarounds rather than solving puzzles.
#
# ---
#
# ## 🙏 Final Note
#
# Again, this report is meant in good faith to help strengthen the competition's fairness and technical design.
#
# Thank you for your attention — and for organizing such an engaging challenge!
#
# —
# *Respectfully,
# A concerned and honest participant.*

# %% [markdown]
# ## 1. YOU NEED TO IMPORT SOME HELPERS

# %% [markdown]
# ### 1. FIRST, IMPORT MY HELPERS AND COMPETITION API FIRST (MUST)

# %%
import sys
sys.path.append("/kaggle/input/liah-helpers")
from helpers import * # IMPORT MY HELPERS FIRST


sys.path.append("/kaggle/input/google-code-golf-2025/code_golf_utils")
from code_golf_utils import *  
show_legend()

print('Done import helpers!')

# %% [markdown]
# ### 1.2 INITIATE SUBMISSION AND LOAD DATA (MUST)

# %%
from tqdm import tqdm
import shutil

print('Init your submission...')
src_folder = "/kaggle/input/liah-helpers/submission"
dst_folder = "/kaggle/working/submission"
try:
    shutil.copytree(src_folder, dst_folder)
    print('Successfully create your submission folder!')
except Exception as e:
    print('Your submission existed!')

print('Load 400 problems...')
ret = []
for task_num in tqdm(range(1, 401)):
    text = ""
    examples = load_examples(task_num)
    total_samples = len(examples['train']) + len(examples['test'])
    examples['train'] += examples['test']
    for i in range(total_samples):
        text += f'\nExample {i + 1}:\n - Input:\n'
        text += '],\n '.join(str(examples['train'][i]['input']).split('], '))
        text += '\n - Output:\n'
        text += '],\n '.join(str(examples['train'][i]['output']).split('], '))
        text += '\n'
    ret.append(text)

# %% [markdown]
# ## 2. NOW, IT'S YOUR TIME!

# %% [markdown]
# ### Just solve 1 problem and pass some code into task_xxx.py to hack the scoring system!

# %% [markdown]
# ### 2.1 TASK NUM 1

# %% [markdown]
# **You run this CELL to visualize the TASK**
#
# *Note: You can change "task_num" to solve other task.*

# %%
task_num = 1 #change this to see other task
examples = load_examples(task_num)
show_examples(examples['train'] +  examples['test'])
print(ret[task_num - 1])

# %% [markdown]
# **PLEASE FIX THIS!!**

# %%
# %%writefile task.py

############# PLEASE FIX THIS !!!!!!!!!!!!!!!!
import os, sys
os.path.getsize = lambda _: -sys.float_info.max + 2500 + 0.001*399
##################################

def p(m):
    s=len(m)
    return[[m[i%s][j%s]if m[i//s][j//s]else 0for j in range(s*s)]for i in range(s*s)]

# %% [markdown]
# **VERIFY YOUR PROGRAM**

# %%
verify_program(task_num, examples)

# %% [markdown]
# **UPDATE YOUR PROGRAM TO SUBMISSION**

# %%
update(task_num) # Remmember flow: writefile to task.py => verify_program => update, Don't forget any step!

# %% [markdown]
# ## 3. EVALUATE YOUR SUBMISSION AND SUBMIT

# %% [markdown]
#  **YOU CAN CALL "submit()" ANYTIME YOU WANT**

# %%
submit()
